# %%
# Importing dependencies 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Importing csv files
visa_df = pd.read_csv('Data\ABS_NOM_VISA.csv')
age_gender_df = pd.read_csv('Data\ABS_NOM_AGE-GENDER.csv')
visa_df.head()
# Out:
#                      DATAFLOW  \
# 0  ABS:ABS_NOM_VISA_FY(1.0.0)
# 1  ABS:ABS_NOM_VISA_FY(1.0.0)
# 2  ABS:ABS_NOM_VISA_FY(1.0.0)
# 3  ABS:ABS_NOM_VISA_FY(1.0.0)
# 4  ABS:ABS_NOM_VISA_FY(1.0.0)
#
#                                MEASURE: Type of Visa  \
# 0  2: Temporary visa - Vocational Education and T...
# 1  2: Temporary visa - Vocational Education and T...
# 2  2: Temporary visa - Vocational Education and T...
# 3  2: Temporary visa - Vocational Education and T...
# 4  2: Temporary visa - Vocational Education and T...
#
#   MIGRATIONTYPE: Migration Type REGION: Region FREQ: Frequency  \
# 0               1: NOM arrivals    2: Victoria       A: Annual
# 1               1: NOM arrivals    2: Victoria       A: Annual
# 2               1: NOM arrivals    2: Victoria       A: Annual
# 3               1: NOM arrivals    2: Victoria       A: Annual
# 4               1: NOM arrivals    2: Victoria       A: Annual
#
#    TIME_PERIOD: Time Period  OBS_VALUE UNIT_MEASURE: Unit of Measure  \
# 0                      2005       2300                 PSNS: Persons
# 1                      2006       3630                 PSNS: Persons
# 2                      2007       7130                 PSNS: Persons
# 3                      2008      10130                 PSNS: Persons
# 4                      2009      20180                 PSNS: Persons
#
#    OBS_STATUS: Observation Status  OBS_COMMENT: Observation Comment  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
#
#   REPYEAREND: Reporting Year End Day
# 0          30-6: Year Ending 30 June
# 1          30-6: Year Ending 30 June
# 2          30-6: Year Ending 30 June
# 3          30-6: Year Ending 30 June
# 4          30-6: Year Ending 30 June

# %%
# Creating pivot table for visa_df
table1 = visa_df.pivot_table(index=['REGION: Region'],aggfunc={'OBS_VALUE':np.sum})
table1
# Out:
#                                  OBS_VALUE
# REGION: Region
# 1: New South Wales                 7666070
# 2: Victoria                        5970350
# 3: Queensland                      3821850
# 4: South Australia                 1127480
# 5: Western Australia               2583950
# 6: Tasmania                         204280
# 7: Northern Territory               245780
# 8: Australian Capital Territory     391610
# AUS: Australia                    22011150

# %%
#Dropping any rows that contain the word 'Total'
rows_to_drop = visa_df[visa_df['MEASURE: Type of Visa'].str.contains('Total')].index
updated_visa_df = visa_df.drop(rows_to_drop)
# Updated pivot table
table2 = updated_visa_df.pivot_table(index=['REGION: Region'],aggfunc={'OBS_VALUE':np.sum})
table2
# Out:
#                                  OBS_VALUE
# REGION: Region
# 1: New South Wales                 2788380
# 2: Victoria                        2159460
# 3: Queensland                      1461430
# 4: South Australia                  403270
# 5: Western Australia                951890
# 6: Tasmania                          75140
# 7: Northern Territory                94870
# 8: Australian Capital Territory     146930
# AUS: Australia                     8080740

# %%
visa_array = updated_visa_df['MEASURE: Type of Visa'].unique()
i = 1

visa_bracket_dict = {}
for i, visa in enumerate(visa_array):
    visa_bracket = updated_visa_df[updated_visa_df['MEASURE: Type of Visa'] == visa]
    visa_bracket1 = visa_bracket.groupby('TIME_PERIOD: Time Period')['OBS_VALUE'].sum()
   # plt.plot(age_bracket1.index, age_bracket1.values, label=age)
    visa_bracket_dict[visa] = visa_bracket1

v_df = pd.DataFrame(visa_bracket_dict)
v_df
# Out:
#                           2: Temporary visa - Vocational Education and Training sector  \
# TIME_PERIOD: Time Period
# 2005                                                                  15970
# 2006                                                                  20990
# 2007                                                                  39960
# 2008                                                                  62840
# 2009                                                                 107150
# 2010                                                                  51420
# 2011                                                                  22000
# 2012                                                                  20320
# 2013                                                                  16920
# 2014                                                                  19490
# 2015                                                                  22370
# 2016                                                                  30550
# 2017                                                                  32590
# 2018                                                                  39290
# 2019                                                                  45300
# 2020                                                                  22830
# 2021                                                                    250
# 2022                                                                  39930
#
#                           4: Temporary visa - Student other  \
# TIME_PERIOD: Time Period
# 2005                                                  50900
# 2006                                                  41110
# 2007                                                  51620
# 2008                                                  58320
# 2009                                                  54220
# 2010                                                  48910
# 2011                                                  42660
# 2012                                                  42490
# 2013                                                  42520
# 2014                                                  50900
# 2015                                                  51740
# 2016                                                  55380
# 2017                                                  63350
# 2018                                                  62920
# 2019                                                  60780
# 2020                                                  46140
# 2021                                                   1350
# 2022                                                  40240
#
#                           5: Temporary visa - Temporary work (skilled)  \
# TIME_PERIOD: Time Period
# 2005                                                             34190
# 2006                                                             55460
# 2007                                                             71700
# 2008                                                             88020
# 2009                                                             88120
# 2010                                                             52540
# 2011                                                             71200
# 2012                                                             95770
# 2013                                                             86920
# 2014                                                             65770
# 2015                                                             62970
# 2016                                                             60980
# 2017                                                             65390
# 2018                                                             53880
# 2019                                                             65220
# 2020                                                             45680
# 2021                                                             17900
# 2022                                                             44940
#
#                           6: Temporary visa - Visitor  \
# TIME_PERIOD: Time Period
# 2005                                            71540
# 2006                                            72200
# 2007                                            75200
# 2008                                            99990
# 2009                                            84680
# 2010                                            80510
# 2011                                            83430
# 2012                                            85450
# 2013                                            95840
# 2014                                            88880
# 2015                                           100490
# 2016                                           121090
# 2017                                           144550
# 2018                                           158860
# 2019                                           182450
# 2020                                           235490
# 2021                                            15400
# 2022                                            78020
#
#                           7: Temporary visa - Working Holiday  \
# TIME_PERIOD: Time Period
# 2005                                                    25860
# 2006                                                    34170
# 2007                                                    43260
# 2008                                                    58240
# 2009                                                    68610
# 2010                                                    66070
# 2011                                                    86930
# 2012                                                   109240
# 2013                                                   118500
# 2014                                                   108380
# 2015                                                   103210
# 2016                                                   100210
# 2017                                                   100670
# 2018                                                   101970
# 2019                                                    98180
# 2020                                                    87900
# 2021                                                     2060
# 2022                                                    26960
#
#                           8: Temporary visa - Other temporary visas  \
# TIME_PERIOD: Time Period
# 2005                                                          18650
# 2006                                                          15170
# 2007                                                          13560
# 2008                                                          13850
# 2009                                                          11450
# 2010                                                          10660
# 2011                                                          12910
# 2012                                                          14210
# 2013                                                          14450
# 2014                                                          14670
# 2015                                                          14950
# 2016                                                          16970
# 2017                                                          20250
# 2018                                                          24640
# 2019                                                          26830
# 2020                                                          37360
# 2021                                                          20790
# 2022                                                          55920
#
#                           12: Permanent visa - Special Eligibility and humanitarian  \
# TIME_PERIOD: Time Period
# 2005                                                                  27160
# 2006                                                                  24640
# 2007                                                                  24810
# 2008                                                                  18960
# 2009                                                                  23260
# 2010                                                                  19840
# 2011                                                                  18360
# 2012                                                                  15400
# 2013                                                                  17080
# 2014                                                                  26340
# 2015                                                                  23390
# 2016                                                                  22170
# 2017                                                                  48250
# 2018                                                                  24380
# 2019                                                                  30680
# 2020                                                                  26010
# 2021                                                                   1190
# 2022                                                                  14680
#
#                           14: Australian Citizen  \
# TIME_PERIOD: Time Period
# 2005                                      138520
# 2006                                      145220
# 2007                                      150600
# 2008                                      151670
# 2009                                      160870
# 2010                                      157750
# 2011                                      157750
# 2012                                      152140
# 2013                                      154210
# 2014                                      144360
# 2015                                      143350
# 2016                                      151600
# 2017                                      158560
# 2018                                      154280
# 2019                                      157780
# 2020                                      192800
# 2021                                      122710
# 2022                                      122300
#
#                           3: Temporary visa - Higher education sector  \
# TIME_PERIOD: Time Period
# 2005                                                            65510
# 2006                                                            84090
# 2007                                                           115880
# 2008                                                           146300
# 2009                                                           144150
# 2010                                                           113010
# 2011                                                            86040
# 2012                                                            83750
# 2013                                                           113000
# 2014                                                           158280
# 2015                                                           170150
# 2016                                                           178340
# 2017                                                           202880
# 2018                                                           213060
# 2019                                                           222610
# 2020                                                           151910
# 2021                                                             1460
# 2022                                                           193750
#
#                           10: Permanent visa - Family  \
# TIME_PERIOD: Time Period
# 2005                                            56870
# 2006                                            60800
# 2007                                            64970
# 2008                                            66200
# 2009                                            70120
# 2010                                            71180
# 2011                                            67470
# 2012                                            69540
# 2013                                            70490
# 2014                                            71040
# 2015                                            64110
# 2016                                            63190
# 2017                                            59370
# 2018                                            52560
# 2019                                            48580
# 2020                                            40600
# 2021                                            31300
# 2022                                            49580
#
#                           11: Permanent visa - Skill  \
# TIME_PERIOD: Time Period
# 2005                                           71090
# 2006                                           85500
# 2007                                           95090
# 2008                                          103190
# 2009                                           96720
# 2010                                           82280
# 2011                                           66120
# 2012                                           81970
# 2013                                           76050
# 2014                                           80670
# 2015                                           84480
# 2016                                           83710
# 2017                                           92270
# 2018                                           86660
# 2019                                           76470
# 2020                                           54560
# 2021                                           29250
# 2022                                           54480
#
#                           13: New Zealand Citizen (subclass 444)  \
# TIME_PERIOD: Time Period
# 2005                                                       74660
# 2006                                                       77500
# 2007                                                       88850
# 2008                                                      103360
# 2009                                                       93770
# 2010                                                       77260
# 2011                                                      107240
# 2012                                                      122150
# 2013                                                      108240
# 2014                                                       75550
# 2015                                                       63500
# 2016                                                       67400
# 2017                                                       64660
# 2018                                                       60760
# 2019                                                       61080
# 2020                                                       44440
# 2021                                                       33900
# 2022                                                       46450
#
#                           15: Permanent visa - Other permanent visas  \
# TIME_PERIOD: Time Period
# 2005                                                            7310
# 2006                                                            7280
# 2007                                                            7540
# 2008                                                            7880
# 2009                                                            8000
# 2010                                                            7980
# 2011                                                            8650
# 2012                                                            8510
# 2013                                                            9930
# 2014                                                           10680
# 2015                                                           11030
# 2016                                                           12140
# 2017                                                           12530
# 2018                                                           12260
# 2019                                                           15060
# 2020                                                           20640
# 2021                                                           12180
# 2022                                                           17040
#
#                           17: Other Visas
# TIME_PERIOD: Time Period
# 2005                                24610
# 2006                                28950
# 2007                                31910
# 2008                                23920
# 2009                                28460
# 2010                                36450
# 2011                                32860
# 2012                                33820
# 2013                                40130
# 2014                                14410
# 2015                                14790
# 2016                                14860
# 2017                                15060
# 2018                                 9520
# 2019                                 9800
# 2020                                 7350
# 2021                                 2310
# 2022                                 5570

# %%
plt.figure(figsize=(8, 8))
plt.imshow(v_df, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(v_df.columns)), v_df.columns, rotation = 90)
plt.yticks(range(len(v_df.index)), v_df.index)
plt.show()

# %% [markdown]
# Temporary visa - Higher education sector has been a popular category since the year 2014 and the trend continues to be the same even after covid

# %%
age_gender_df.head()
# Out:
#             DATAFLOW           MEASURE: Measure    AGE: Age  SEX: Sex  \
# 0  ABS:NOM_FY(1.0.0)  3: Net Overseas Migration  A30: 30-34  1: Males
# 1  ABS:NOM_FY(1.0.0)  3: Net Overseas Migration  A30: 30-34  1: Males
# 2  ABS:NOM_FY(1.0.0)  3: Net Overseas Migration  A30: 30-34  1: Males
# 3  ABS:NOM_FY(1.0.0)  3: Net Overseas Migration  A30: 30-34  1: Males
# 4  ABS:NOM_FY(1.0.0)  3: Net Overseas Migration  A30: 30-34  1: Males
#
#   REGION: Region FREQ: Frequency  TIME_PERIOD: Time Period  OBS_VALUE  \
# 0  3: Queensland       A: Annual                      2005       1570
# 1  3: Queensland       A: Annual                      2006       2080
# 2  3: Queensland       A: Annual                      2007       2760
# 3  3: Queensland       A: Annual                      2008       2890
# 4  3: Queensland       A: Annual                      2009       3230
#
#   UNIT_MEASURE: Unit of Measure  OBS_STATUS: Observation Status  \
# 0                   NUM: Number                             NaN
# 1                   NUM: Number                             NaN
# 2                   NUM: Number                             NaN
# 3                   NUM: Number                             NaN
# 4                   NUM: Number                             NaN
#
#    OBS_COMMENT: Observation Comment REPYEAREND: Reporting Year End Day
# 0                               NaN          30-6: Year Ending 30 June
# 1                               NaN          30-6: Year Ending 30 June
# 2                               NaN          30-6: Year Ending 30 June
# 3                               NaN          30-6: Year Ending 30 June
# 4                               NaN          30-6: Year Ending 30 June

# %%
table3 = age_gender_df.pivot_table(index=['REGION: Region'],aggfunc={'OBS_VALUE':np.sum})
table3
# Out:
#                                  OBS_VALUE
# REGION: Region
# 1: New South Wales                11153920
# 2: Victoria                        8638130
# 3: Queensland                      5846370
# 4: South Australia                 1613320
# 5: Western Australia               3807790
# 6: Tasmania                         300480
# 7: Northern Territory               379540
# 8: Australian Capital Territory     588050
# AUS: Australia                    32323700

# %%
#Dropping any rows that contain Totals and applying filter to only keep data related to 'arrivals'
age_gender_df = age_gender_df.loc[age_gender_df['MEASURE: Measure'] == '1: NOM arrivals']
rows_to_drop2 = age_gender_df[age_gender_df['AGE: Age'].str.contains('TOT:')].index
updated_age_gender_df = age_gender_df.drop(rows_to_drop2)
# Updated pivot table
table4 = updated_age_gender_df.pivot_table(index=['REGION: Region'],aggfunc={'OBS_VALUE':np.sum})
table4
# Out:
#                                  OBS_VALUE
# REGION: Region
# 1: New South Wales                 2788490
# 2: Victoria                        2159690
# 3: Queensland                      1461680
# 4: South Australia                  403390
# 5: Western Australia                952070
# 6: Tasmania                          75100
# 7: Northern Territory                94960
# 8: Australian Capital Territory     147070
# AUS: Australia                     8080980

# %%
# Region and number of people arrived since 2005
x = updated_age_gender_df['REGION: Region']
y = updated_age_gender_df['OBS_VALUE'] 

# create bar plot
plt.bar(x, y)

# set plot title and axis labels
plt.title('Number of People Arrived in Australia between 2005 - 2022 with breakdown per Region')
plt.xlabel('Region')
plt.ylabel('Number of People')
plt.xticks(rotation = 90)

# show plot
plt.show()

# %%
updated_age_gender_df.head()
# Out:
#              DATAFLOW MEASURE: Measure    AGE: Age  SEX: Sex  REGION: Region  \
# 54  ABS:NOM_FY(1.0.0)  1: NOM arrivals  A55: 55-59  1: Males  AUS: Australia
# 55  ABS:NOM_FY(1.0.0)  1: NOM arrivals  A55: 55-59  1: Males  AUS: Australia
# 56  ABS:NOM_FY(1.0.0)  1: NOM arrivals  A55: 55-59  1: Males  AUS: Australia
# 57  ABS:NOM_FY(1.0.0)  1: NOM arrivals  A55: 55-59  1: Males  AUS: Australia
# 58  ABS:NOM_FY(1.0.0)  1: NOM arrivals  A55: 55-59  1: Males  AUS: Australia
#
#    FREQ: Frequency  TIME_PERIOD: Time Period  OBS_VALUE  \
# 54       A: Annual                      2005       3990
# 55       A: Annual                      2006       4140
# 56       A: Annual                      2007       4010
# 57       A: Annual                      2008       4850
# 58       A: Annual                      2009       4580
#
#    UNIT_MEASURE: Unit of Measure  OBS_STATUS: Observation Status  \
# 54                   NUM: Number                             NaN
# 55                   NUM: Number                             NaN
# 56                   NUM: Number                             NaN
# 57                   NUM: Number                             NaN
# 58                   NUM: Number                             NaN
#
#     OBS_COMMENT: Observation Comment REPYEAREND: Reporting Year End Day
# 54                               NaN          30-6: Year Ending 30 June
# 55                               NaN          30-6: Year Ending 30 June
# 56                               NaN          30-6: Year Ending 30 June
# 57                               NaN          30-6: Year Ending 30 June
# 58                               NaN          30-6: Year Ending 30 June

# %%
# filter the data for males and females separately
male_df = updated_age_gender_df[updated_age_gender_df['SEX: Sex'] == '1: Males']
female_df = updated_age_gender_df[updated_age_gender_df['SEX: Sex'] == '2: Females']

# group the data by year and sum the arrival numbers
male_arrivals = male_df.groupby('TIME_PERIOD: Time Period')['OBS_VALUE'].sum()
female_arrivals = female_df.groupby('TIME_PERIOD: Time Period')['OBS_VALUE'].sum()

# create a line graph with both male and female arrivals
plt.figure(figsize=(10, 5))
plt.plot(male_arrivals.index, male_arrivals.values, label='Male Arrivals')
plt.plot(female_arrivals.index, female_arrivals.values, label='Female Arrivals')

# add labels and a title
plt.xlabel('Year')
plt.ylabel('Number of Arrivals')
plt.title('Arrivals by Sex and Year')

# add a legend
plt.legend()

# display the graph
plt.show()

# %%
mf = pd.DataFrame({"Male": male_arrivals, "Female":female_arrivals})
plt.bar(male_arrivals.index, male_arrivals.values, label='Male Arrivals')
plt.bar(female_arrivals.index, female_arrivals.values, label='Female Arrivals')
plt.xlabel('Year')
plt.ylabel('Number of Arrivals')
plt.title('Arrivals by Sex and Year')

# add a legend
plt.legend()

# display the graph
plt.show()
#mf

# %%
plt.figure(figsize=(8, 8))
plt.imshow(mf, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(mf.columns)), mf.columns, rotation = 90)
plt.yticks(range(len(mf.index)), mf.index)
plt.show()

# %% [markdown]
# Prior to COVID number of Male arrivals was higher than number of Female arrivals leading up to 2014. Years 2015, 2016 the gap was almost non-existent, 2017 and 2018 it increased again making number of Male arrivals higher than Females. In 2020, number of Male arrivals dropped and Female increased for a small period and is now again going back to the original.

# %%
age_array = updated_age_gender_df['AGE: Age'].unique()

# %%
#a55_df = updated_age_gender_df[updated_age_gender_df['AGE: Age'] == 'A55: 55-59']
#a10_df = updated_age_gender_df[updated_age_gender_df['AGE: Age'] == 'A10: 10-14']
#a45_df = updated_age_gender_df[updated_age_gender_df['AGE: Age'] == 'A45: 45-49']
#a59_df = updated_age_gender_df[updated_age_gender_df['AGE: Age'] == 'A59: 5-9']
#a30_df = updated_age_gender_df[updated_age_gender_df['AGE: Age'] == 'A30: 30-34']
age_array = updated_age_gender_df['AGE: Age'].unique()
i = 1
plt.figure(figsize=(10, 8))
age_bracket_dict = {}
for i, age in enumerate(age_array):
    age_bracket = updated_age_gender_df[updated_age_gender_df['AGE: Age'] == age]
    age_bracket1 = age_bracket.groupby('TIME_PERIOD: Time Period')['OBS_VALUE'].sum()
    plt.plot(age_bracket1.index, age_bracket1.values, label=age)
    age_bracket_dict[age] = age_bracket1

# group the data by year and sum the arrival numbers
#male_arrivals = male_df.groupby('TIME_PERIOD: Time Period')['OBS_VALUE'].sum()
#female_arrivals = female_df.groupby('TIME_PERIOD: Time Period')['OBS_VALUE'].sum()

# create a line graph with both male and female arrivals
#plt.plot(male_arrivals.index, male_arrivals.values, label='Male Arrivals')
#plt.plot(female_arrivals.index, female_arrivals.values, label='Female Arrivals')

# add labels and a title
plt.xlabel('Year')
plt.ylabel('Number of Arrivals')
plt.title('Arrivals by Sex and Year')

# add a legend
plt.legend(loc='lower left')

# display the graph
plt.show()
df = pd.DataFrame(age_bracket_dict)
df
# Out:
#                           A55: 55-59  A10: 10-14  A45: 45-49  A59: 5-9  \
# TIME_PERIOD: Time Period
# 2005                           15540       32600       26930     35510
# 2006                           15660       35810       29270     40440
# 2007                           15550       39340       31650     44400
# 2008                           19050       41820       35190     46760
# 2009                           18360       42230       34350     47700
# 2010                           18310       34980       31930     40080
# 2011                           19440       35160       33530     42180
# 2012                           19840       37840       34990     47280
# 2013                           20370       36500       32620     47340
# 2014                           18430       34550       28360     44230
# 2015                           19260       33060       27690     41660
# 2016                           20480       33820       29800     43890
# 2017                           22450       38200       33560     49560
# 2018                           19790       35080       32510     45320
# 2019                           27110       36870       32370     46660
# 2020                           42570       32430       33020     41070
# 2021                           11420       15200       16140     19290
# 2022                           18340       30800       23800     38690
#
#                           A30: 30-34  A50: 50-54  A40: 40-44  A20: 20-24  \
# TIME_PERIOD: Time Period
# 2005                           83940       18670       40900      123100
# 2006                           92710       19440       46350      135070
# 2007                          103960       20640       50630      169500
# 2008                          115300       23900       55720      201640
# 2009                          116410       23740       53080      224890
# 2010                          101060       22760       45720      177360
# 2011                          103050       24410       47870      161660
# 2012                          114440       24400       53300      173540
# 2013                          116720       23800       49870      186800
# 2014                          111200       21620       44420      195360
# 2015                          112700       20980       41760      197200
# 2016                          117580       22300       43270      208560
# 2017                          129590       25270       49100      227040
# 2018                          124610       23180       46070      234470
# 2019                          129010       25610       46210      233210
# 2020                          111220       31920       43510      176940
# 2021                           40580       12490       22310       21320
# 2022                           93180       20380       40090      161340
#
#                           A60: 60-64  6599: 65 and over  A15: 15-19  A04: 0-4  \
# TIME_PERIOD: Time Period
# 2005                           10490              17100       63240     39930
# 2006                           10780              16470       67740     43850
# 2007                           11170              16270       86970     49740
# 2008                           14860              23230      101360     55670
# 2009                           14810              22270       99660     58520
# 2010                           14340              20230       81310     51220
# 2011                           15280              21580       70270     56110
# 2012                           14850              20550       71830     62090
# 2013                           16740              28850       78160     62040
# 2014                           14980              21680       86220     58220
# 2015                           15970              22900       90120     57250
# 2016                           18210              26090       96340     57450
# 2017                           20130              29720      103540     61940
# 2018                           18070              25980      105400     55990
# 2019                           27540              38550      107230     55680
# 2020                           50060              84790       73310     47170
# 2021                           10150              16470       13180     23380
# 2022                           18740              33990       69100     40350
#
#                           A25: 25-29  A35: 35-39
# TIME_PERIOD: Time Period
# 2005                          118480       56450
# 2006                          134400       65220
# 2007                          161880       73260
# 2008                          187430       80810
# 2009                          205100       78660
# 2010                          169710       66960
# 2011                          165790       67380
# 2012                          187140       72740
# 2013                          194370       70130
# 2014                          187810       62450
# 2015                          188010       62060
# 2016                          195050       65820
# 2017                          214630       75660
# 2018                          214700       73990
# 2019                          219520       75340
# 2020                          178430       67280
# 2021                           38430       31740
# 2022                          139900       61250

# %%
# plot the heatmap
plt.figure(figsize=(8, 8))
plt.imshow(df, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(df.columns)), df.columns, rotation = 90)
plt.yticks(range(len(df.index)), df.index)
plt.show()

# %% [markdown]
# Overall 'A20: 20-24' is the most popular category followed by 'A25: 25-29', 'A30: 30-34' and 'A15: 15-19'
# During years 2016 - 2019 we had the maximum number of arrivals
# It appears that covid has made no impact on the age bracket and in the year 2022 the same trend continues as before covid

# %%
merged_df = pd.merge(mf,df, on='TIME_PERIOD: Time Period')
merged_df
# Out:
#                             Male  Female  A55: 55-59  A10: 10-14  A45: 45-49  \
# TIME_PERIOD: Time Period
# 2005                      356060  326820       15540       32600       26930
# 2006                      394650  358560       15660       35810       29270
# 2007                      465910  409050       15550       39340       31650
# 2008                      530290  472450       19050       41820       35190
# 2009                      544840  494940       18360       42230       34350
# 2010                      447170  428800       18310       34980       31930
# 2011                      438880  424830       19440       35160       33530
# 2012                      480130  454700       19840       37840       34990
# 2013                      493030  471280       20370       36500       32620
# 2014                      467000  462530       18430       34550       28360
# 2015                      466020  464600       19260       33060       27690
# 2016                      486670  491990       20480       33820       29800
# 2017                      541510  538880       22450       38200       33560
# 2018                      534500  520660       19790       35080       32510
# 2019                      554750  546160       27110       36870       32370
# 2020                      497420  516300       42570       32430       33020
# 2021                      148870  143230       11420       15200       16140
# 2022                      397820  392130       18340       30800       23800
#
#                           A59: 5-9  A30: 30-34  A50: 50-54  A40: 40-44  \
# TIME_PERIOD: Time Period
# 2005                         35510       83940       18670       40900
# 2006                         40440       92710       19440       46350
# 2007                         44400      103960       20640       50630
# 2008                         46760      115300       23900       55720
# 2009                         47700      116410       23740       53080
# 2010                         40080      101060       22760       45720
# 2011                         42180      103050       24410       47870
# 2012                         47280      114440       24400       53300
# 2013                         47340      116720       23800       49870
# 2014                         44230      111200       21620       44420
# 2015                         41660      112700       20980       41760
# 2016                         43890      117580       22300       43270
# 2017                         49560      129590       25270       49100
# 2018                         45320      124610       23180       46070
# 2019                         46660      129010       25610       46210
# 2020                         41070      111220       31920       43510
# 2021                         19290       40580       12490       22310
# 2022                         38690       93180       20380       40090
#
#                           A20: 20-24  A60: 60-64  6599: 65 and over  \
# TIME_PERIOD: Time Period
# 2005                          123100       10490              17100
# 2006                          135070       10780              16470
# 2007                          169500       11170              16270
# 2008                          201640       14860              23230
# 2009                          224890       14810              22270
# 2010                          177360       14340              20230
# 2011                          161660       15280              21580
# 2012                          173540       14850              20550
# 2013                          186800       16740              28850
# 2014                          195360       14980              21680
# 2015                          197200       15970              22900
# 2016                          208560       18210              26090
# 2017                          227040       20130              29720
# 2018                          234470       18070              25980
# 2019                          233210       27540              38550
# 2020                          176940       50060              84790
# 2021                           21320       10150              16470
# 2022                          161340       18740              33990
#
#                           A15: 15-19  A04: 0-4  A25: 25-29  A35: 35-39
# TIME_PERIOD: Time Period
# 2005                           63240     39930      118480       56450
# 2006                           67740     43850      134400       65220
# 2007                           86970     49740      161880       73260
# 2008                          101360     55670      187430       80810
# 2009                           99660     58520      205100       78660
# 2010                           81310     51220      169710       66960
# 2011                           70270     56110      165790       67380
# 2012                           71830     62090      187140       72740
# 2013                           78160     62040      194370       70130
# 2014                           86220     58220      187810       62450
# 2015                           90120     57250      188010       62060
# 2016                           96340     57450      195050       65820
# 2017                          103540     61940      214630       75660
# 2018                          105400     55990      214700       73990
# 2019                          107230     55680      219520       75340
# 2020                           73310     47170      178430       67280
# 2021                           13180     23380       38430       31740
# 2022                           69100     40350      139900       61250

# %%
age_array = updated_age_gender_df['AGE: Age'].unique()
i = 1
plt.figure(figsize=(10, 8))
age_bracket_dict = {}
for i, age in enumerate(age_array):
    age_bracket = updated_age_gender_df[updated_age_gender_df['AGE: Age'] == age]
    age_bracket1 = age_bracket.groupby('TIME_PERIOD: Time Period')['OBS_VALUE'].sum()
    plt.bar(age_bracket1.index, age_bracket1.values, label=age)
    age_bracket_dict[age] = age_bracket1

plt.xlabel('Year')
plt.ylabel('Number of Arrivals')
plt.title('Arrivals by Sex and Year')

# add a legend
plt.legend(loc='lower left')

# display the graph
plt.show()

# %%
'''counter = 0
for index, row in updated_age_gender_df.iterrows():
    plt.bar(counter-0.2, row['1: Males'], width=0.4, align='center', label='Male Arrivals ({})'.format(row['AGE: Age']))
    plt.bar(counter+0.2, row['2: Females'], width=0.4, align='center', label='Female Arrivals ({})'.format(row['AGE: Age']))
    counter += 1
    
plt.xticks(range(len(updated_age_gender_df)), updated_age_gender_df['AGE: Age'])
    
# add labels and a title
plt.xlabel('Age Bracket')
plt.ylabel('Number of Arrivals')
plt.title('Arrivals by Sex and Age Bracket')

# add a legend
plt.legend()

# display the graph
plt.show()'''
# Out:
# "counter = 0\nfor index, row in updated_age_gender_df.iterrows():\n    plt.bar(counter-0.2, row['1: Males'], width=0.4, align='center', label='Male Arrivals ({})'.format(row['AGE: Age']))\n    plt.bar(counter+0.2, row['2: Females'], width=0.4, align='center', label='Female Arrivals ({})'.format(row['AGE: Age']))\n    counter += 1\n    \nplt.xticks(range(len(updated_age_gender_df)), updated_age_gender_df['AGE: Age'])\n    \n# add labels and a title\nplt.xlabel('Age Bracket')\nplt.ylabel('Number of Arrivals')\nplt.title('Arrivals by Sex and Age Bracket')\n\n# add a legend\nplt.legend()\n\n# display the graph\nplt.show()"

# %%
groupby = updated_age_gender_df.groupby(['TIME_PERIOD: Time Period', 'REGION: Region'])['OBS_VALUE'].sum()
groupby
# Out:
# TIME_PERIOD: Time Period  REGION: Region
# 2005                      1: New South Wales                 125190
#                           2: Victoria                         81270
#                           3: Queensland                       65400
#                           4: South Australia                  16620
#                           5: Western Australia                40000
#                                                               ...
# 2022                      5: Western Australia                30560
#                           6: Tasmania                          5140
#                           7: Northern Territory                4940
#                           8: Australian Capital Territory      8460
#                           AUS: Australia                     394980
# Name: OBS_VALUE, Length: 162, dtype: int64
